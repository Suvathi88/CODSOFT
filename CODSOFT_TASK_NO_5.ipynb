# %%
import numpy as np
import pandas as pd
df=pd.read_csv("creditcard.csv")
df
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 0           0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1           0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2           1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3           1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4           2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...       ...       ...       ...       ...       ...       ...       ...
# 120896  75998  1.501845 -1.193147  0.066789 -1.600847 -1.259865 -0.268558
# 120897  75999 -0.340455  1.201756  1.314094  0.053134  0.111616 -0.959891
# 120898  75999 -1.089161  0.115364  1.501978  0.700866  0.493027 -0.220268
# 120899  76000  0.213729  0.623136 -0.259558 -0.152127  2.262088  3.579712
# 120900  76001 -0.367988  1.108999  0.787889  1.043825 -0.336914 -0.554318
#
#               V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
df.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  120901.000000  120901.000000  120901.000000  120901.000000
# mean        0.000000      -0.254384      -0.008025       0.678328
# std         1.000004       1.836627       1.634281       1.290767
# min        -2.489238     -56.407510     -72.715728     -33.680984
# 25%        -0.611341      -1.023037      -0.583732       0.174366
# 50%         0.095983      -0.264902       0.089895       0.752889
# 75%         0.818767       1.155820       0.756160       1.373702
# max         1.493963       1.960497      18.902453       9.382558
#
#                   V4             V5             V6             V7  \
# count  120901.000000  120901.000000  120901.000000  120901.000000
# mean        0.153237      -0.283571       0.088069      -0.114509
# std         1.335416       1.329840       1.291924       1.189611
# min        -5.172595     -42.147898     -26.160506     -31.764946
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df['Amount']=scaler.fit_transform(df['Amount'].values.reshape(-1,1))
df['Time']=scaler.fit_transform(df['Time'].values.reshape(-1,1))
df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 0      -2.489238 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1      -2.489238  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2      -2.489186 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3      -2.489186 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4      -2.489133 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...          ...       ...       ...       ...       ...       ...       ...
# 120896  1.493806  1.501845 -1.193147  0.066789 -1.600847 -1.259865 -0.268558
# 120897  1.493858 -0.340455  1.201756  1.314094  0.053134  0.111616 -0.959891
# 120898  1.493858 -1.089161  0.115364  1.501978  0.700866  0.493027 -0.220268
# 120899  1.493910  0.213729  0.623136 -0.259558 -0.152127  2.262088  3.579712
# 120900  1.493963 -0.367988  1.108999  0.787889  1.043825 -0.336914 -0.554318
#
# ...

# %%
x = df.drop('Class', axis=1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print(y_train.value_counts(normalize=True))
# Out:
# Class
# 0.0    0.998046
# 1.0    0.001954
# Name: proportion, dtype: float64

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE(random_state=42)
x_train_res,y_train_res=sm.fit_resample(x_train,y_train)
print(y_train_res.value_counts(normalize=True))
# Out:
# Class
# 0.0    0.5
# 1.0    0.5
# Name: proportion, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, precision_recall_fscore_support
from collections import Counter

# %%
log_reg = LogisticRegression(max_iter=1000, random_state=42)
log_reg.fit(x_train_res, y_train_res)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(x_train_res, y_train_res)
y_pred_log_reg = log_reg.predict(x_test)
y_pred_rf = rf.predict(x_test)

# %%
print("\nLogistic Regression Performance:")
print(classification_report(y_test, y_pred_log_reg))
print("\nRandom Forest Performance:")
print(classification_report(y_test, y_pred_rf))
# Out:
# Logistic Regression Performance:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.98      0.99     24121
#          1.0       0.09      0.82      0.16        60
#
#     accuracy                           0.98     24181
#    macro avg       0.54      0.90      0.58     24181
# weighted avg       1.00      0.98      0.99     24181
#
#
# Random Forest Performance:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     24121
#          1.0       1.00      0.77      0.87        60
#
#     accuracy                           1.00     24181
#    macro avg       1.00      0.88      0.93     24181
# weighted avg       1.00      1.00      1.00     24181

# %%
recision_rf, recall_rf, f1_rf, _ = precision_recall_fscore_support(y_test, y_pred_rf, average='binary')
precision_log, recall_log, f1_log, _ = precision_recall_fscore_support(y_test, y_pred_log_reg, average='binary')
print(f"Logistic Regression - Precision: {precision_log:.4f}, Recall: {recall_log:.4f}, F1-Score: {f1_log:.4f}")
# Out:
# Logistic Regression - Precision: 0.0899, Recall: 0.8167, F1-Score: 0.1620
